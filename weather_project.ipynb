# %% [markdown]
# <a href="https://colab.research.google.com/github/Reena6878/lohan/blob/infotrixs/weather_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install requests

# %%
import requests
import time
import os

title="****** Weather Checking Application ******"
print(title.center(60))
def get_weather(city, api_key):
    url = f"http://api.weatherapi.com/v1/current.json?key={api_key}&q={city}"
    response = requests.get(url)
    if response.status_code == 200:
      data = response.json()

      if 'error' in data:
          print("City not found or weather data not available.")
      else:
          current = data['current']

          temperature = current['temp_c']
          condition = current['condition']['text']
          humidity = current['humidity']
          wind_kph = current['wind_kph']


          print(f"Weather in {city}:")
          print(f"Condition: {condition}")
          print(f"Temperature: {temperature}°C")
          print(f"Humidity: {humidity}%")
          print(f"Wind Speed: {wind_kph} km/h")

          print("\n" + "=" * 30)  # Adding separator
#
#def clear_console():
    #os.system('cls' if os.name == 'nt' else 'clear')


def refresh(f_city,api_key):
  while True:
        for city in f_city:
            #clear_console()
            get_weather(city, api_key)

            time.sleep(15)

def main():
    api_key = "325c9d50493445558ee144842230211"
    f_city=['Delhi','Haryana','Mumbai']

    new_city = input("Enter a city or press Enter to continue: ")
    if new_city:
      f_city.append(new_city)


    refresh(f_city,api_key)


    get_weather(city_name, api_key)





if __name__ == "__main__":
  main()
# Out:
#          ****** Weather Checking Application ******
# Enter a city or press Enter to continue: jind
# Weather in Delhi:
# Condition: Clear
# Temperature: 0.9°C
# Humidity: 89%
# Wind Speed: 6.1 km/h
#
# ...
# Weather in Haryana:
# Condition: Sunny
# Temperature: 20.0°C
# Humidity: 43%
# Wind Speed: 4.7 km/h
#
# ...
# Weather in Mumbai:
# Condition: Mist
# Temperature: 27.0°C
# Humidity: 89%
# Wind Speed: 6.8 km/h
#
# ...
# Weather in jind:
# Condition: Sunny
# Temperature: 21.1°C
# Humidity: 38%
# Wind Speed: 3.6 km/h
#
# ...
# Weather in Delhi:
# Condition: Clear
# Temperature: 0.9°C
# Humidity: 89%
# Wind Speed: 6.1 km/h
#
# ...
# Weather in Haryana:
# Condition: Sunny
# Temperature: 20.0°C
# Humidity: 43%
# Wind Speed: 4.7 km/h
#
# ...
# Weather in Mumbai:
# Condition: Mist
# Temperature: 27.0°C
# Humidity: 89%
# Wind Speed: 6.8 km/h
#
# ...
# Weather in jind:
# Condition: Sunny
# Temperature: 21.1°C
# Humidity: 38%
# Wind Speed: 3.6 km/h
#
# ...
# Weather in Delhi:
# Condition: Clear
# Temperature: 0.9°C
# Humidity: 89%
# ...
