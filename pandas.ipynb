# %% [markdown]
# <a href="https://colab.research.google.com/github/Reena6878/lohan/blob/master/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import pandas as pd

# %%
data=pd.read_csv("/content/df.csv")

# %%
data.head()
# Out:
#    age gender   review education purchased
# 0   97      f    good         ug       yes
# 1   45      m  average        pg       yes
# 2   23      f     poor        pg        no
# 3   56      m    good         ug        no
# 4   78      m     poor        pg       yes

# %%
data.tail()
# Out:
#     age gender   review education purchased
# 10   90      m     poor        ug       yes
# 11   34      f  average        ug        no
# 12   23      m     poor        pg        no
# 13   67      f    good         ug       yes
# 14   89      m    good         pg        no

# %%
data.shape
# Out:
# (15, 5)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        15 non-null     int64
#  1   gender     15 non-null     object
#  2   review     15 non-null     object
#  3   education  15 non-null     object
#  4   purchased  15 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 728.0+ bytes

# %%
data.describe()
# Out:
#              age
# count  15.000000
# mean   57.666667
# std    29.273749
# min     5.000000
# 25%    34.000000
# 50%    56.000000
# 75%    83.500000
# max    97.000000

# %%
#how to fetch column and row in given database
data['age']
# Out:
# 0     97
# 1     45
# 2     23
# 3     56
# 4     78
# 5     90
# 6      5
# 7     34
# 8     56
# 9     78
# 10    90
# 11    34
# 12    23
# 13    67
# 14    89
# Name: age, dtype: int64

# %%
type(data['age'])
# Out:
# pandas.core.series.Series

# %%
#fetch multiple columns
data[['age','gender','education']]
# Out:
#     age gender education
# 0    97      f        ug
# 1    45      m        pg
# 2    23      f        pg
# 3    56      m        ug
# 4    78      m        pg
# 5    90      f        ug
# 6     5      m        ug
# 7    34      f        pg
# 8    56      m        pg
# 9    78      f        pg
# 10   90      m        ug
# 11   34      f        ug
# 12   23      m        pg
# 13   67      f        ug
# 14   89      m        pg

# %%
data[['age','gender','education']].shape
# Out:
# (15, 3)

# %%
data.iloc[0]#fetch first row in the dataframe
# Out:
# age             97
# gender           f
# review       good
# education       ug
# purchased      yes
# Name: 0, dtype: object

# %%
data.iloc[1:5]#more than one rows fetching
# Out:
#    age gender   review education purchased
# 1   45      m  average        pg       yes
# 2   23      f     poor        pg        no
# 3   56      m    good         ug        no
# 4   78      m     poor        pg       yes

# %%
data.iloc[[1,5,6]]#desire rows fetching
# Out:
#    age gender    review education purchased
# 1   45      m   average        pg       yes
# 5   90      f      poor        ug        no
# 6    5      m  excelent        ug       yes

# %%
data.iloc[:,[1,3]]
# Out:
#    gender education purchased
# 0       f        ug       yes
# 1       m        pg       yes
# 2       f        pg        no
# 3       m        ug        no
# 4       m        pg       yes
# 5       f        ug        no
# 6       m        ug       yes
# 7       f        pg        no
# 8       m        pg       yes
# 9       f        pg        no
# 10      m        ug       yes
# 11      f        ug        no
# 12      m        pg        no
# 13      f        ug       yes
# 14      m        pg        no
#    gender education purchased
# 0       f        ug       yes
# 1       m        pg       yes
# 2       f        pg        no
# 3       m        ug        no
# 4       m        pg       yes
# 5       f        ug        no
# 6       m        ug       yes
# 7       f        pg        no
# 8       m        pg       yes
# 9       f        pg        no
# 10      m        ug       yes
# 11      f        ug        no
# 12      m        pg        no
# 13      f        ug       yes
# ...

# %%
mask=data['review']=='poor'

# %%
data[mask]
# Out:
#     age gender review education purchased
# 2    23      f   poor        pg        no
# 4    78      m   poor        pg       yes
# 5    90      f   poor        ug        no
# 10   90      m   poor        ug       yes
# 12   23      m   poor        pg        no

# %%
def get_education_count(education):
  mask=data['education']==education
  return data[mask].shape[0]

# %%
get_education_count('ug')
# Out:
# 7

# %%
mask1=data['education']=='ug'
mask2=data['age']>50
data[mask1 + mask2]
# Out:
#     age gender    review education purchased
# 0    97      f     good         ug       yes
# 3    56      m     good         ug        no
# 4    78      m      poor        pg       yes
# 5    90      f      poor        ug        no
# 6     5      m  excelent        ug       yes
# 8    56      m  excelent        pg       yes
# 9    78      f     good         pg        no
# 10   90      m      poor        ug       yes
# 11   34      f   average        ug        no
# 13   67      f     good         ug       yes
# 14   89      m     good         pg        no

# %%
data['age'].value_counts()# to count the no of values
# Out:
# 23    2
# 56    2
# 78    2
# 90    2
# 34    2
# 97    1
# 45    1
# 5     1
# 67    1
# 89    1
# Name: age, dtype: int64

# %%
#data visulization
import matplotlib.pyplot as plt

# %%
data['age'].value_counts().head().plot(kind='barh')#horizantal bar plot
# Out:
# <Axes: >

# %%
data['age'].plot(kind='pie')
# Out:
# <Axes: ylabel='age'>

# %%
data['age'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
myseries=data['age'].value_counts()
myseries
# Out:
# 23    2
# 56    2
# 78    2
# 90    2
# 34    2
# 97    1
# 45    1
# 5     1
# 67    1
# 89    1
# Name: age, dtype: int64

# %%
myseries[78]
# Out:
# 2

# %%
#sort method
data['age'].sort_values(ascending=False)
# Out:
# 0     97
# 5     90
# 10    90
# 14    89
# 4     78
# 9     78
# 13    67
# 3     56
# 8     56
# 1     45
# 7     34
# 11    34
# 2     23
# 12    23
# 6      5
# Name: age, dtype: int64

# %%
data.sort_values('gender',inplace=True)#sorting acc. to gender and permanent changes using inplace

# %%
data
# Out:
#     age gender    review education purchased
# 0    97      f     good         ug       yes
# 2    23      f      poor        pg        no
# 5    90      f      poor        ug        no
# 7    34      f     good         pg        no
# 9    78      f     good         pg        no
# 11   34      f   average        ug        no
# 13   67      f     good         ug       yes
# 1    45      m   average        pg       yes
# 3    56      m     good         ug        no
# 4    78      m      poor        pg       yes
# 6     5      m  excelent        ug       yes
# 8    56      m  excelent        pg       yes
# 10   90      m      poor        ug       yes
# 12   23      m      poor        pg        no
# 14   89      m     good         pg        no

# %%
data.sort_values(['review','age'])#sorting on the basis of review and age
# Out:
#     age gender    review education purchased
# 11   34      f   average        ug        no
# 1    45      m   average        pg       yes
# 6     5      m  excelent        ug       yes
# 8    56      m  excelent        pg       yes
# 7    34      f     good         pg        no
# 3    56      m     good         ug        no
# 13   67      f     good         ug       yes
# 9    78      f     good         pg        no
# 14   89      m     good         pg        no
# 0    97      f     good         ug       yes
# 2    23      f      poor        pg        no
# 12   23      m      poor        pg        no
# 4    78      m      poor        pg       yes
# 5    90      f      poor        ug        no
# 10   90      m      poor        ug       yes

# %%
#functions
#remove duplicates
data.drop_duplicates(subset='review')
# Out:
#     age gender    review education purchased
# 0    97      f     good         ug       yes
# 2    23      f      poor        pg        no
# 11   34      f   average        ug        no
# 6     5      m  excelent        ug       yes

# %%
data
# Out:
#     age gender    review education purchased
# 0    97      f     good         ug       yes
# 2    23      f      poor        pg        no
# 5    90      f      poor        ug        no
# 7    34      f     good         pg        no
# 9    78      f     good         pg        no
# 11   34      f   average        ug        no
# 13   67      f     good         ug       yes
# 1    45      m   average        pg       yes
# 3    56      m     good         ug        no
# 4    78      m      poor        pg       yes
# 6     5      m  excelent        ug       yes
# 8    56      m  excelent        pg       yes
# 10   90      m      poor        ug       yes
# 12   23      m      poor        pg        no
# 14   89      m     good         pg        no

# %%
import numpy as np

# %%
import pandas as pd

# %%
data=pd.read_csv("/content/df.csv")

# %%
data
# Out:
#     age gender    review education purchased
# 0    97      f     good         ug       yes
# 1    45      m   average        pg       yes
# 2    23      f      poor        pg        no
# 3    56      m     good         ug        no
# 4    78      m      poor        pg       yes
# 5    90      f      poor        ug        no
# 6     5      m  excelent        ug       yes
# 7    34      f     good         pg        no
# 8    56      m  excelent        pg       yes
# 9    78      f     good         pg        no
# 10   90      m      poor        ug       yes
# 11   34      f   average        ug        no
# 12   23      m      poor        pg        no
# 13   67      f     good         ug       yes
# 14   89      m     good         pg        no

# %%
data.drop_duplicates("review",keep='last')
# Out:
#     age gender    review education purchased
# 8    56      m  excelent        pg       yes
# 11   34      f   average        ug        no
# 12   23      m      poor        pg        no
# 14   89      m     good         pg        no

# %%
#groupby
sector=data.groupby('review')

# %%
sector

# %%
len(data)#no. of rows
# Out:
# 15

# %%
len(sector)
# Out:
# 4

# %%
sector.size()
# Out:
# review
# average     2
# excelent    2
# good        6
# poor        5
# dtype: int64

# %%
sector.first()
# Out:
#           age gender education purchased
# review
# average    45      m        pg       yes
# excelent    5      m        ug       yes
# good       97      f        ug       yes
# poor       23      f        pg        no

# %%
sector.last()
# Out:
#           age gender education purchased
# review
# average    34      f        ug        no
# excelent   56      m        pg       yes
# good       89      m        pg        no
# poor       23      m        pg        no

# %%
sector.groups
# Out:
# {'average': [1, 11], 'excelent': [6, 8], 'good ': [0, 3, 7, 9, 13, 14], 'poor': [2, 4, 5, 10, 12]}

# %%
data.iloc[14,:]
# Out:
# age             89
# gender           m
# review       good
# education       pg
# purchased       no
# Name: 14, dtype: object

# %%
sector.get_group("poor")
# Out:
#     age gender review education purchased
# 2    23      f   poor        pg        no
# 4    78      m   poor        pg       yes
# 5    90      f   poor        ug        no
# 10   90      m   poor        ug       yes
# 12   23      m   poor        pg        no

# %%
sector.mean()
# Out:
# <ipython-input-26-2e854d1f189a>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sector.mean()
#                 age
# review
# average   39.500000
# excelent  30.500000
# good      70.166667
# poor      60.800000

# %%
# Out:
#    age gender   review education purchased
# 0   97      f    good         ug       yes
# 1   45      m  average        pg       yes
# 2   23      f     poor        pg        no
# 3   56      m    good         ug        no
# 4   78      m     poor        pg       yes

# %%
import seaborn as sns

# %%
dd=sns.load_dataset("titanic")

# %%
dd.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
dd.groupby(['survived','pclass'])['survived','pclass'].sum()
# Out:
# <ipython-input-59-8e515abcc60a>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   dd.groupby(['survived','pclass'])['survived','pclass'].sum()
#                  survived  pclass
# survived pclass
# 0        1              0      80
#          2              0     194
#          3              0    1116
# 1        1            136     136
#          2             87     174
#          3            119     357

# %%
dd.groupby(['survived','pclass'])['survived','pclass'].sum().drop_duplicates()
# Out:
# <ipython-input-60-20671612b16b>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   dd.groupby(['survived','pclass'])['survived','pclass'].sum().drop_duplicates()
#                  survived  pclass
# survived pclass
# 0        1              0      80
#          2              0     194
#          3              0    1116
# 1        1            136     136
#          2             87     174
#          3            119     357

# %%
#pivot table

# %%
dd.pivot_table(index=(['pclass','sex']),columns='embark_town',values='survived',aggfunc='mean')
# Out:
# embark_town    Cherbourg  Queenstown  Southampton
# pclass sex
# 1      female   0.976744    1.000000     0.958333
#        male     0.404762    0.000000     0.354430
# 2      female   1.000000    1.000000     0.910448
#        male     0.200000    0.000000     0.154639
# 3      female   0.652174    0.727273     0.375000
#        male     0.232558    0.076923     0.128302

# %%
#applying pivot table

# %%
mask=dd['survived']==0
zero=dd[mask]
zero.shape
# Out:
# (549, 15)

# %%
zero.pivot_table(index='pclass')
# Out:
# <ipython-input-72-47bd6084e089>:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   zero.pivot_table(index='pclass')
#         adult_male        age     alone       fare     parch     sibsp  \
# pclass
# 1         0.962500  43.695312  0.637500  64.684007  0.300000  0.287500
# 2         0.938144  33.544444  0.701031  19.412328  0.144330  0.319588
# 3         0.755376  26.555556  0.685484  13.669364  0.384409  0.672043
#
#         survived
# pclass
# 1              0
# 2              0
# 3              0

# %%
#corr function
df=sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.heatmap(df.corr())
# Out:
# <ipython-input-84-aa4f4450a243>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
#rename cols
df1=pd.read_csv("/content/sample_data/california_housing_test.csv")

# %%
df1.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
df1.rename(columns={'total_rooms':'Rooms','total_bedrooms':'bedrooms'},inplace=True)

# %%
df1.head()
# Out:
#    longitude  latitude  housing_median_age   Rooms  bedrooms  population  \
# 0    -122.05     37.37                27.0  3885.0     661.0      1537.0
# 1    -118.30     34.26                43.0  1510.0     310.0       809.0
# 2    -117.81     33.78                27.0  3589.0     507.0      1484.0
# 3    -118.36     33.82                28.0    67.0      15.0        49.0
# 4    -119.67     36.33                19.0  1241.0     244.0       850.0
#
#    households  median_income  median_house_value
# 0       606.0         6.6085            344700.0
# 1       277.0         3.5990            176500.0
# 2       495.0         5.7934            270500.0
# 3        11.0         6.1359            330000.0
# 4       237.0         2.9375             81700.0

# %%
#set index
df1.set_index('housing_median_age')
# Out:
#                     longitude  latitude   Rooms  bedrooms  population  \
# housing_median_age
# 27.0                  -122.05     37.37  3885.0     661.0      1537.0
# 43.0                  -118.30     34.26  1510.0     310.0       809.0
# 27.0                  -117.81     33.78  3589.0     507.0      1484.0
# 28.0                  -118.36     33.82    67.0      15.0        49.0
# 19.0                  -119.67     36.33  1241.0     244.0       850.0
# ...                       ...       ...     ...       ...         ...
# 23.0                  -119.86     34.42  1450.0     642.0      1258.0
# 27.0                  -118.14     34.06  5257.0    1082.0      3496.0
# 10.0                  -119.70     36.30   956.0     201.0       693.0
# 40.0                  -117.12     34.10    96.0      14.0        46.0
# 42.0                  -119.63     34.42  1765.0     263.0       753.0
#
#                     households  median_income  median_house_value
# housing_median_age
# ...

# %%
df1['Rooms'].value_counts().reset_index()
# Out:
#        index  Rooms
# 0      907.0      5
# 1     1787.0      5
# 2     1778.0      5
# 3     1966.0      5
# 4     1499.0      4
# ...      ...    ...
# 2210  1132.0      1
# 2211  3199.0      1
# 2212  1433.0      1
# 2213  4602.0      1
# 2214  5257.0      1
#
# [2215 rows x 2 columns]

# %%
#handling missing values

# %%
df.dropna(how='all').shape
# Out:
# (891, 15)
